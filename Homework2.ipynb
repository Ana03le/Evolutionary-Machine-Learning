# %%
# #######################################################################
#  HW2 (due on 3/02/19):                                                #
# To apply Evolution Strategies (or Particle Swarm Optimization)        #
#to a neural network model for a prediction task using LSTM             #                        #
#########################################################################

########################
## CIS 600 HOMEWORK2  ##
## Anagha Fatale      ##
## SUID 438039600     ##
########################


import pandas as pd
import numpy
import keras
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from sklearn.metrics import confusion_matrix,mean_squared_error
import math
from __future__ import division
# fix random seed for reproducibility
numpy.random.seed(7)
from sklearn.model_selection import train_test_split
from keras import backend as K
import numpy as np
import tensorflow as tf
from sklearn.svm import SVC  
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.utils.generic_utils import get_custom_objects
from keras import optimizers
from keras.layers import Dense, Activation, Dropout
import matplotlib.pyplot as plt 
from neupy import algorithms, environment
import copy
import random
BIG_SCORE = 1.e6
N = 30 # number of particles
STEPS = 10 # number of steps
LOSS = 'mse' # Loss function
BATCH_SIZE = 32 # Size of batches to train on
# Out:
# /Users/anaghafatale/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Users/anaghafatale/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /Users/anaghafatale/anaconda3/lib/python3.6/site-packages/theano/configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
## Below Code is taken from : https://github.com/mike-holcomb/PSOkeras/tree/master/psokeras ##

class ProgressBar:
    def __init__(self, steps, updates=10):
        self.step = 0
        self.step_size = (steps // updates)
        self.total_steps = steps
        self.updates = updates
        bar = self._make_bar(0)
        print(bar)

    def update(self, i):
        if i % self.step_size > 0:
            return
        self.step = i // self.step_size
        bar = self._make_bar(i)
        print(bar)

    def done(self):
        self.step = self.total_steps
        bar = self._make_bar(self.updates)
        print(bar)

    def _make_bar(self, x):
        bar = "["
        for x in range(self.updates):
            print("\r")
            if x < self.step:
                bar += "="
            else:
                bar = " "
        bar += "]"
        print(bar)
        return bar

# %%
class Particle:
    def __init__(self, model, params):
        self.model = model
        self.params = params
        self.init_weights = model.get_weights()
        self.velocities = [None] * len(self.init_weights)
        self.length = len(self.init_weights)
        for i, layer in enumerate(self.init_weights):
            self.velocities[i] = np.random.rand(*layer.shape) / 5 - 0.10
            # self.velocities[i] = np.zeros(layer.shape)

        self.best_weights = None
        self.best_score = BIG_SCORE

    def get_score(self, x, y, update=True):
        print(self.model.metrics_names)
        #5 local_score = self.model.evaluate(x, y, verbose=0)
        pred = scaler.inverse_transform(self.model.predict(x))
        # print(pred[:0])
        # Prepare Y data to also be on the original scale for interpretability.
        orig_data = scaler.inverse_transform([y])
        # print(orig_data[0])
        # Calculate RMSE.
        local_score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
        print("Local RMSE score:",local_score)
        if local_score < self.best_score and update:
            self.best_score = local_score
            self.best_weights = self.model.get_weights()

        return local_score

    def _update_velocities(self, global_best_weights, depth):
        new_velocities = [None] * len(self.init_weights)
        weights = self.model.get_weights()
        local_rand, global_rand = random.random(), random.random()

        for i, layer in enumerate(weights):
            if i >= depth:
                new_velocities[i] = self.velocities[i]
                continue
            new_v = self.params['acc'] * self.velocities[i]
            new_v = new_v + self.params['local_acc'] * local_rand * (self.best_weights[i] - layer)
            new_v = new_v + self.params['global_acc'] * global_rand * (global_best_weights[i] - layer)
            new_velocities[i] = new_v

        self.velocities = new_velocities

    def _update_weights(self, depth):
        old_weights = self.model.get_weights()
        new_weights = [None] * len(old_weights)
        for i, layer in enumerate(old_weights):
            if i>= depth:
                new_weights[i] = layer
                continue
            new_w = layer + self.velocities[i]
            new_weights[i] = new_w

        self.model.set_weights(new_weights)

    def step(self, x, y, global_best_weights,depth=None):
        if depth is None:
            depth = self.length
        self._update_velocities(global_best_weights, depth)
        self._update_weights(depth)
        return self.get_score(x, y)

    def get_best_weights(self):
        return self.best_weights

# %%
BIG_SCORE = 1.e6  # type: float


class Optimizer:
    def __init__(self, model, loss,
                 n=10,
                 acceleration=0.1,
                 local_rate=1.0,
                 global_rate=1.0):

        self.n_particles = n
        self.structure = model.to_json()
        self.particles = [None] * n
        self.loss = loss
        self.length = len(model.get_weights())

        params = {'acc': acceleration, 'local_acc': local_rate, 'global_acc': global_rate}

        for i in range(n-1):
            m = keras.models.model_from_json(self.structure)
            m.compile(loss=loss,optimizer='sgd')
            self.particles[i] = Particle(m, params)

        self.particles[n-1] = Particle(model, params)

        self.global_best_weights = None
        self.global_best_score = BIG_SCORE

    def fit(self, x, y, steps=0, batch_size=32):
        num_batches = x.shape[0] // batch_size

        for i, p in enumerate(self.particles):
            local_score = p.get_score(x, y)
            if local_score < self.global_best_score:
                self.global_best_score = local_score
                self.global_best_weights = p.get_best_weights()

        print("PSO -- Initial best score :")
        print(self.global_best_score)
        bar = ProgressBar(steps, updates=20)

        for i in range(steps):
            for j in range(num_batches):
                x_ = x[j*batch_size:(j+1)*batch_size,:]
                y_ = y[j*batch_size:(j+1)*batch_size]

                for p in self.particles:
                    local_score = p.step(x_, y_, self.global_best_weights)
                    #print("....",local_score)
                    if local_score < self.global_best_score:
                        self.global_best_score = local_score
                        self.global_best_weights = p.get_best_weights()

            #bar.update(i)

        bar.done()

    def get_best_model(self):
        best_model = keras.models.model_from_json(self.structure)
        best_model.set_weights(self.global_best_weights)
        best_model.compile(loss=self.loss,optimizer='sgd')
        return best_model

# %%
##### Below code is taken from : https://github.com/mike-holcomb/PSOkeras/blob/master/example.py ##########

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense


N = 30 # number of particles
STEPS = 10 # number of steps
LOSS = 'mse' # Loss function
BATCH_SIZE = 32 # Size of batches to train on


def build_model(loss):
    """
    Builds test Keras model for predicting Iris classifications
    :param loss (str): Type of loss - must be one of Keras accepted keras losses
    :return: Keras dense model of predefined structure
    """
    model = Sequential()
    model.add(LSTM(4, input_shape = (1, window_size)))
    model.add(Dense(1))
    model.compile(loss = 'mse', optimizer = "sgd" )
    return model


def RNN(x_train, y_train):
    """
    Runs N number of backpropagation model training simulations
    :param x_train: x values to train on
    :param y_train: target labels to train with
    :return: best model run as measured by LOSS
    """
    best_model = None
    best_score = 100.0

    print("RNN called..")
    for i in range(1):
        model_s = build_model(LOSS)
        model_s.fit(x_train, y_train,epochs = 10, batch_size = 8,verbose = 2)
        scores = model_s.evaluate(x_train, y_train, batch_size=BATCH_SIZE, verbose=0)
        pred = scaler.inverse_transform(model_s.predict(x_train))
        orig_data = scaler.inverse_transform([y_train])
        train_score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
        print("RMSE Score without pyswarm Optimization is :",train_score)
        if train_score < best_score:
            best_model = model_s
            best_score = train_score
    return best_model


if __name__ == "__main__":


# Part I: First run the recurrent neural network model
#Below code is referred from the website:
#https://www.altumintelligence.com/articles/a/Time-Series-Prediction-Using-LSTM-Deep-Neural-Networks 

    data = pd.read_csv("international-airline-passengers.csv", usecols = [1], engine = "python", skipfooter = 3)
    # Get the raw data values from the pandas data frame.
    data_raw = data.values.astype("float32")

    # We apply the MinMax scaler from sklearn
    # to normalize data in the (0, 1) interval.
    scaler = MinMaxScaler(feature_range = (0, 1))
    dataset = scaler.fit_transform(data_raw)
    TRAIN_SIZE = 0.60

    train_size = int(len(dataset) * TRAIN_SIZE)
    test_size = len(dataset) - train_size
    train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]
    print("Number of entries (training set, test set): " + str((len(train), len(test))))
    
    def create_dataset(dataset, window_size = 1):
        data_X, data_Y = [], []
        for i in range(len(dataset) - window_size - 1):
            a = dataset[i:(i + window_size), 0]
            data_X.append(a)
            data_Y.append(dataset[i + window_size, 0])
        return(np.array(data_X), np.array(data_Y))

    
    
    # Create test and training sets for one-step-ahead regression.
    window_size = 1
    x_train, y_train = create_dataset(train, window_size)
    x_test, y_test = create_dataset(test, window_size)
    print("Original training data shape:")
    print(x_train.shape)

    # Reshape the input data into appropriate form for Keras.
    x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
    x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))
    print("New training data shape:")
    print(x_train.shape)

    model_s = RNN(x_train,y_train)
    
    #Part II: Then run the particle swarm optimization
    #First build model to train on (primarily used for structure, also included in swarm)
    
    model_p = build_model(LOSS)

    # Instantiate optimizer with model, loss function, and hyperparameters
    # N is Number of particles
    # acceleratin Contribution of recursive particle velocity (acceleration)
    # local_rate is contribution of locally best weights to new velocity
    # global_rate is Contribution of globally best weights to new velocity
    pso = Optimizer(model=model_p,loss=LOSS,n=N,acceleration=1.0, local_rate=0.6,global_rate=0.4)   

    # Train model on provided data
    pso.fit(x_train, y_train, steps=STEPS, batch_size=BATCH_SIZE)

    # Get a copy of the model with the globally best weights
    model_p = pso.get_best_model()
    scores = model_p.evaluate(x_train, y_train, batch_size=BATCH_SIZE, verbose=0)
        
    pred = scaler.inverse_transform(model_p.predict(x_train))
    orig_data = scaler.inverse_transform([y_train])
    
    train_score = math.sqrt(mean_squared_error(orig_data[0], pred[:, 0]))
    print("RMSE Score with pyswarm Optimization is :",train_score)
# Out:
# Number of entries (training set, test set): (86, 58)
# Original training data shape:
# (84, 1)
# New training data shape:
# (84, 1, 1)
# RNN called..
# Epoch 1/10
#  - 1s - loss: 0.0385
# Epoch 2/10
#  - 0s - loss: 0.0284
# Epoch 3/10
#  - 0s - loss: 0.0222
# Epoch 4/10
#  - 0s - loss: 0.0182
# Epoch 5/10
#  - 0s - loss: 0.0158
# Epoch 6/10
#  - 0s - loss: 0.0142
# Epoch 7/10
#  - 0s - loss: 0.0133
# Epoch 8/10
#  - 0s - loss: 0.0128
# Epoch 9/10
#  - 0s - loss: 0.0124
# Epoch 10/10
#  - 0s - loss: 0.0122
# RMSE Score without pyswarm Optimization is : 56.980781835071234
# ['loss']
# Local RMSE score: 114.22389232204237
# ['loss']
# Local RMSE score: 100.5329877448042
# ['loss']
# Local RMSE score: 105.72517042105231
# ['loss']
# Local RMSE score: 104.86386582368829
# ['loss']
# Local RMSE score: 130.33183212071663
# ['loss']
# Local RMSE score: 109.7098171289539
# ['loss']
# Local RMSE score: 98.35971550314439
# ['loss']
# Local RMSE score: 129.08642106832886
# ['loss']
# Local RMSE score: 118.80251437729201
# ['loss']
# Local RMSE score: 104.0970357205116
# ['loss']
# Local RMSE score: 110.22232554449481
# ['loss']
# Local RMSE score: 98.71081752668763
# ['loss']
# Local RMSE score: 114.55584041590534
# ['loss']
# Local RMSE score: 122.8282058859835
# ['loss']
# Local RMSE score: 129.7508397909665
# ['loss']
# Local RMSE score: 113.47017744598134
# ['loss']
# Local RMSE score: 114.12262512260283
# ['loss']
# Local RMSE score: 109.82733787340682
# ['loss']
# Local RMSE score: 96.70241728424136
# ['loss']
# Local RMSE score: 102.55007690616723
# ['loss']
# Local RMSE score: 135.26904334902488
# ['loss']
# Local RMSE score: 110.50387807953099
# ['loss']
# Local RMSE score: 133.74086300262587
# ['loss']
# Local RMSE score: 119.88097445452644
# ['loss']
# Local RMSE score: 104.06555745111152
# ['loss']
# Local RMSE score: 105.03340197607305
# ['loss']
# Local RMSE score: 110.70502115397201
# ['loss']
# Local RMSE score: 113.19515972317659
# ['loss']
# Local RMSE score: 94.64909429262494
# ['loss']
# Local RMSE score: 104.98202399300921
# PSO -- Initial best score :
# 94.64909429262494
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ]
#  ]
# ['loss']
# Local RMSE score: 54.74153283286997
# ['loss']
# Local RMSE score: 23.247149658121828
# ['loss']
# Local RMSE score: 58.48200251402969
# ['loss']
# Local RMSE score: 75.46357094672214
# ['loss']
# Local RMSE score: 94.32844353091598
# ['loss']
# Local RMSE score: 24.265500269635453
# ['loss']
# Local RMSE score: 33.69859100882974
# ['loss']
# Local RMSE score: 31.88039640685173
# ['loss']
# Local RMSE score: 70.82133468802836
# ['loss']
# Local RMSE score: 88.51235755125622
# ['loss']
# Local RMSE score: 84.32187140466293
# ['loss']
# Local RMSE score: 49.51751555152741
# ['loss']
# Local RMSE score: 29.95729906208921
# ['loss']
# Local RMSE score: 90.95420098687026
# ['loss']
# Local RMSE score: 83.88804783637086
# ['loss']
# Local RMSE score: 75.67265908877252
# ['loss']
# Local RMSE score: 67.64396270504605
# ['loss']
# Local RMSE score: 46.388613679958574
# ['loss']
# Local RMSE score: 32.86405407856871
# ['loss']
# Local RMSE score: 83.97812060667009
# ['loss']
# Local RMSE score: 64.69619674222693
# ['loss']
# Local RMSE score: 36.465303041977016
# ['loss']
# Local RMSE score: 27.099009206378522
# ['loss']
# Local RMSE score: 38.83485643183426
# ['loss']
# Local RMSE score: 40.11065539797259
# ['loss']
# Local RMSE score: 25.630382117683244
# ['loss']
# Local RMSE score: 48.80065001482113
# ['loss']
# Local RMSE score: 65.06512898903875
# ['loss']
# Local RMSE score: 112.43064732834367
# ['loss']
# Local RMSE score: 62.61387062747202
# ['loss']
# Local RMSE score: 118.06919671232122
# ['loss']
# Local RMSE score: 37.922730595156914
# ['loss']
# Local RMSE score: 116.96090222890811
# ['loss']
# Local RMSE score: 157.98335288763056
# ['loss']
# Local RMSE score: 176.98949481927735
# ['loss']
# Local RMSE score: 39.22980774909552
# ['loss']
# Local RMSE score: 72.8229862976385
# ['loss']
# Local RMSE score: 57.385083618206565
# ['loss']
# Local RMSE score: 121.83110764259375
# ['loss']
# Local RMSE score: 176.8931385683436
# ['loss']
# Local RMSE score: 159.6604066978187
# ['loss']
# Local RMSE score: 94.82862810538904
# ['loss']
# Local RMSE score: 54.69869454046918
# ['loss']
# Local RMSE score: 167.712169359414
# ['loss']
# Local RMSE score: 141.91495014733567
# ['loss']
# Local RMSE score: 146.4739657343752
# ['loss']
# Local RMSE score: 114.09226804226608
# ['loss']
# Local RMSE score: 93.63312807523285
# ['loss']
# Local RMSE score: 78.35672513839457
# ['loss']
# Local RMSE score: 162.93495793259515
# ['loss']
# Local RMSE score: 100.28184034328632
# ['loss']
# Local RMSE score: 72.6661174196669
# ['loss']
# Local RMSE score: 29.6252116672198
# ['loss']
# Local RMSE score: 74.72308573681288
# ['loss']
# Local RMSE score: 84.5007675358027
# ['loss']
# Local RMSE score: 44.32972979509803
# ['loss']
# Local RMSE score: 103.71957172787987
# ['loss']
# Local RMSE score: 120.34676990033905
# ['loss']
# Local RMSE score: 171.70103238812098
# ['loss']
# Local RMSE score: 141.12864831938748
# ['loss']
# Local RMSE score: 57.47490395528557
# ['loss']
# Local RMSE score: 56.053994363115535
# ['loss']
# Local RMSE score: 47.024569013451355
# ['loss']
# Local RMSE score: 80.7398598472363
# ['loss']
# Local RMSE score: 123.77767648955037
# ['loss']
# Local RMSE score: 55.52899604009261
# ['loss']
# Local RMSE score: 23.8230396105713
# ['loss']
# Local RMSE score: 60.708670678701004
# ['loss']
# Local RMSE score: 44.57526854450711
# ['loss']
# Local RMSE score: 108.78968658501883
# ['loss']
# Local RMSE score: 86.63549658768724
# ['loss']
# Local RMSE score: 29.62761032946708
# ['loss']
# Local RMSE score: 31.903440062585283
# ['loss']
# Local RMSE score: 79.71851874265532
# ['loss']
# Local RMSE score: 64.56999271288953
# ['loss']
# Local RMSE score: 77.9227852027522
# ['loss']
# Local RMSE score: 34.646117357720385
# ['loss']
# Local RMSE score: 29.270210537737828
# ['loss']
# Local RMSE score: 25.00221304205644
# ['loss']
# Local RMSE score: 94.06094084554023
# ['loss']
# Local RMSE score: 23.01702432594931
# ['loss']
# Local RMSE score: 28.042865970994676
# ['loss']
# Local RMSE score: 84.08563740386582
# ['loss']
# Local RMSE score: 36.57324915574382
# ['loss']
# Local RMSE score: 23.967569216663126
# ['loss']
# Local RMSE score: 52.27352416218054
# ['loss']
# Local RMSE score: 43.51994648754824
# ['loss']
# Local RMSE score: 31.479178261429293
# ['loss']
# Local RMSE score: 61.43201585292127
# ['loss']
# Local RMSE score: 74.13012323980311
# ['loss']
# Local RMSE score: 108.52203834960451
# ['loss']
# Local RMSE score: 28.95584446580249
# ['loss']
# Local RMSE score: 80.47428594777634
# ['loss']
# Local RMSE score: 86.52599007294336
# ['loss']
# Local RMSE score: 173.23479544102477
# ['loss']
# Local RMSE score: 27.041474947055825
# ['loss']
# Local RMSE score: 50.50267518696376
# ['loss']
# Local RMSE score: 28.629927425080663
# ['loss']
# Local RMSE score: 70.50465052854308
# ['loss']
# Local RMSE score: 135.53914205333294
# ['loss']
# Local RMSE score: 99.1784842062858
# ['loss']
# Local RMSE score: 56.33348712882849
# ['loss']
# Local RMSE score: 51.017694792477386
# ['loss']
# Local RMSE score: 83.47199471749802
# ['loss']
# Local RMSE score: 73.30781201865034
# ['loss']
# Local RMSE score: 113.33041830339343
# ['loss']
# Local RMSE score: 52.08976776698465
# ['loss']
# Local RMSE score: 65.99057835963119
# ['loss']
# Local RMSE score: 57.73646253611133
# ['loss']
# Local RMSE score: 136.48388501408257
# ['loss']
# Local RMSE score: 40.295595501625904
# ['loss']
# Local RMSE score: 40.329030287797735
# ['loss']
# Local RMSE score: 28.67072881430744
# ['loss']
# Local RMSE score: 30.105999729181374
# ['loss']
# Local RMSE score: 49.2991831585997
# ['loss']
# Local RMSE score: 35.124116453355406
# ['loss']
# Local RMSE score: 74.20790121633026
# ['loss']
# Local RMSE score: 35.902032889942674
# ['loss']
# Local RMSE score: 67.99060830164872
# ['loss']
# Local RMSE score: 99.35890691921345
# ['loss']
# Local RMSE score: 31.537706177681926
# ['loss']
# Local RMSE score: 34.77327122820534
# ['loss']
# Local RMSE score: 22.690728707151095
# ['loss']
# Local RMSE score: 28.79381484617322
# ['loss']
# Local RMSE score: 90.16791776865173
# ['loss']
# Local RMSE score: 23.37016738794332
# ['loss']
# Local RMSE score: 33.287517194655045
# ['loss']
# Local RMSE score: 46.950478195165225
# ['loss']
# Local RMSE score: 20.997549200234875
# ['loss']
# Local RMSE score: 63.01609091292583
# ['loss']
# Local RMSE score: 24.61894488887523
# ['loss']
# Local RMSE score: 18.487238206264923
# ['loss']
# Local RMSE score: 24.594022757160346
# ['loss']
# Local RMSE score: 21.630905768416536
# ['loss']
# Local RMSE score: 23.378324871189328
# ['loss']
# Local RMSE score: 27.404739702494904
# ['loss']
# Local RMSE score: 33.61184139452697
# ['loss']
# Local RMSE score: 24.27461285050118
# ['loss']
# Local RMSE score: 21.044286811053578
# ['loss']
# Local RMSE score: 57.91723277709373
# ['loss']
# Local RMSE score: 36.179010031561475
# ['loss']
# Local RMSE score: 27.778868858803555
# ['loss']
# Local RMSE score: 25.151440622636926
# ['loss']
# Local RMSE score: 77.37449700716405
# ['loss']
# Local RMSE score: 17.499825274210064
# ['loss']
# Local RMSE score: 21.654941092568304
# ['loss']
# Local RMSE score: 19.221649563836397
# ['loss']
# Local RMSE score: 31.903632785819067
# ['loss']
# Local RMSE score: 30.498258467047478
# ['loss']
# Local RMSE score: 20.84370033280464
# ['loss']
# Local RMSE score: 44.364667920182285
# ['loss']
# Local RMSE score: 63.44489882597563
# ['loss']
# Local RMSE score: 39.92226325311177
# ['loss']
# Local RMSE score: 25.03524944374777
# ['loss']
# Local RMSE score: 92.36417952856577
# ['loss']
# Local RMSE score: 152.33031848749252
# ['loss']
# Local RMSE score: 41.07773443548434
# ['loss']
# Local RMSE score: 30.047839266665907
# ['loss']
# Local RMSE score: 30.22397624181641
# ['loss']
# Local RMSE score: 68.80395373325848
# ['loss']
# Local RMSE score: 40.3287017413763
# ['loss']
# Local RMSE score: 30.016254514308503
# ['loss']
# Local RMSE score: 87.72789047604427
# ['loss']
# Local RMSE score: 23.869691763062402
# ['loss']
# Local RMSE score: 35.62774567038796
# ['loss']
# Local RMSE score: 33.56687600914992
# ['loss']
# Local RMSE score: 23.9874992011262
# ['loss']
# Local RMSE score: 27.687487788421265
# ['loss']
# Local RMSE score: 23.801371417230914
# ['loss']
# Local RMSE score: 62.65631236308788
# ['loss']
# Local RMSE score: 27.460683934311568
# ['loss']
# Local RMSE score: 30.47756928529808
# ['loss']
# Local RMSE score: 125.90971872115277
# ['loss']
# Local RMSE score: 43.186780677534514
# ['loss']
# Local RMSE score: 19.454882993418707
# ['loss']
# Local RMSE score: 93.49987464078994
# ['loss']
# Local RMSE score: 41.040203273295546
# ['loss']
# Local RMSE score: 21.450695520585246
# ['loss']
# Local RMSE score: 22.827202114052426
# ['loss']
# Local RMSE score: 26.84395614463536
# ['loss']
# Local RMSE score: 26.236175879362694
# ['loss']
# Local RMSE score: 37.792887367003246
# ['loss']
# Local RMSE score: 28.516964861248372
# ['loss']
# Local RMSE score: 70.0139945952192
# ['loss']
# Local RMSE score: 28.042081294829682
# ['loss']
# Local RMSE score: 119.4268537198106
# ['loss']
# Local RMSE score: 27.183549439925915
# ['loss']
# Local RMSE score: 29.54375058118049
# ['loss']
# Local RMSE score: 38.99889022524901
# ['loss']
# Local RMSE score: 44.15890087328021
# ['loss']
# Local RMSE score: 30.539231289504887
# ['loss']
# Local RMSE score: 16.730996989117457
# ['loss']
# Local RMSE score: 37.60033283892269
# ['loss']
# Local RMSE score: 32.93208460338235
# ['loss']
# Local RMSE score: 77.03423131036317
# ['loss']
# Local RMSE score: 36.502382390692205
# ['loss']
# Local RMSE score: 49.94107343930419
# ['loss']
# Local RMSE score: 17.461878408694197
# ['loss']
# Local RMSE score: 33.015568305230765
# ['loss']
# Local RMSE score: 21.71858661172209
# ['loss']
# Local RMSE score: 34.615790562717436
# ['loss']
# Local RMSE score: 14.311451349878771
# ['loss']
# Local RMSE score: 78.2820904986223
# ['loss']
# Local RMSE score: 43.391010720767255
# ['loss']
# Local RMSE score: 16.918527290747306
# ['loss']
# Local RMSE score: 128.08283870024638
# ['loss']
# Local RMSE score: 24.069527100703073
# ['loss']
# Local RMSE score: 17.008445666271243
# ['loss']
# Local RMSE score: 39.59613027883971
# ['loss']
# Local RMSE score: 64.5824053720586
# ['loss']
# Local RMSE score: 20.199162349271738
# ['loss']
# Local RMSE score: 70.23666157060062
# ['loss']
# Local RMSE score: 29.97040592555226
# ['loss']
# Local RMSE score: 50.85612703904246
# ['loss']
# Local RMSE score: 51.66606702041683
# ['loss']
# Local RMSE score: 202.20577080593822
# ['loss']
# Local RMSE score: 37.74979964891595
# ['loss']
# Local RMSE score: 27.497918195852648
# ['loss']
# Local RMSE score: 21.02103865744152
# ['loss']
# Local RMSE score: 39.276718770539105
# ['loss']
# Local RMSE score: 27.944721889848303
# ['loss']
# Local RMSE score: 21.521659263688065
# ['loss']
# Local RMSE score: 90.05995709449881
# ['loss']
# Local RMSE score: 21.97124392405865
# ['loss']
# Local RMSE score: 100.50108295916931
# ['loss']
# Local RMSE score: 22.11649239259534
# ['loss']
# Local RMSE score: 26.393256394831365
# ['loss']
# Local RMSE score: 30.36678180291306
# ['loss']
# Local RMSE score: 20.1545760648275
# ['loss']
# Local RMSE score: 24.558210394140783
# ['loss']
# Local RMSE score: 42.71479674145742
# ['loss']
# Local RMSE score: 25.047032580209365
# ['loss']
# Local RMSE score: 127.61485515819314
# ['loss']
# Local RMSE score: 24.05013795502751
# ['loss']
# Local RMSE score: 20.254602080786
# ['loss']
# Local RMSE score: 112.98565202790886
# ['loss']
# Local RMSE score: 38.5143127715069
# ['loss']
# Local RMSE score: 56.75474584585702
# ['loss']
# Local RMSE score: 33.03291854722734
# ['loss']
# Local RMSE score: 33.93411324360341
# ['loss']
# Local RMSE score: 16.244849930113293
# ['loss']
# Local RMSE score: 18.655497545427593
# ['loss']
# Local RMSE score: 15.769847482361138
# ['loss']
# Local RMSE score: 36.54006769137878
# ['loss']
# Local RMSE score: 79.5983429770299
# ['loss']
# Local RMSE score: 105.47220851962989
# ['loss']
# Local RMSE score: 19.92463228405283
# ['loss']
# Local RMSE score: 28.237200685546988
# ['loss']
# Local RMSE score: 23.94317541281112
# ['loss']
# Local RMSE score: 75.68298130692182
# ['loss']
# Local RMSE score: 20.71090372284114
# ['loss']
# Local RMSE score: 13.759837268391069
# ['loss']
# Local RMSE score: 25.606784441739208
# ['loss']
# Local RMSE score: 17.139530515787733
# ['loss']
# Local RMSE score: 50.90085399038571
# ['loss']
# Local RMSE score: 27.555304131299096
# ['loss']
# Local RMSE score: 32.0315216084933
# ['loss']
# Local RMSE score: 59.664927215257656
# ['loss']
# Local RMSE score: 15.070749368015923
# ['loss']
# Local RMSE score: 23.941284711182234
# ['loss']
# Local RMSE score: 46.507750543719304
# ['loss']
# Local RMSE score: 22.300867294392756
# ['loss']
# Local RMSE score: 72.03947367527923
# ['loss']
# Local RMSE score: 37.702742750380516
# ['loss']
# Local RMSE score: 14.038632526544431
# ['loss']
# Local RMSE score: 17.11291819707961
# ['loss']
# Local RMSE score: 15.500237466803988
# ['loss']
# Local RMSE score: 28.78091973903143
# ['loss']
# Local RMSE score: 16.015926617906956
# ['loss']
# Local RMSE score: 15.418350766063439
# ['loss']
# Local RMSE score: 36.62577578768299
# ['loss']
# Local RMSE score: 28.5084198508291
# ['loss']
# Local RMSE score: 33.51016139124202
# ['loss']
# Local RMSE score: 23.682548911107535
# ['loss']
# Local RMSE score: 98.40457531506394
# ['loss']
# Local RMSE score: 28.694687961265416
# ['loss']
# Local RMSE score: 26.57765888801043
# ['loss']
# Local RMSE score: 20.18822168294176
# ['loss']
# Local RMSE score: 31.248948135651023
# ['loss']
# Local RMSE score: 42.59248191345343
# ['loss']
# Local RMSE score: 34.71129847951445
# ['loss']
# Local RMSE score: 23.07053143965071
# ['loss']
# Local RMSE score: 28.773895286318403
# ['loss']
# Local RMSE score: 37.43766313419268
# ['loss']
# Local RMSE score: 33.033525696608855
# ['loss']
# Local RMSE score: 20.348471340791335
# ['loss']
# Local RMSE score: 19.384998109596452
# ['loss']
# Local RMSE score: 45.597110252840395
# ['loss']
# Local RMSE score: 34.340248372244794
# ['loss']
# Local RMSE score: 20.686607397472393
# ['loss']
# Local RMSE score: 131.31299944312823
# ['loss']
# Local RMSE score: 23.842993034694924
# ['loss']
# Local RMSE score: 23.630027107462503
# ['loss']
# Local RMSE score: 33.71715496574918
# ['loss']
# Local RMSE score: 20.962996674082994
# ['loss']
# Local RMSE score: 53.82724406422792
# ['loss']
# Local RMSE score: 37.318803876808715
# ['loss']
# Local RMSE score: 48.2679003912647
# ['loss']
# Local RMSE score: 22.953214253355437
# ['loss']
# Local RMSE score: 76.46083193340884
# ['loss']
# Local RMSE score: 56.9101050829223
# ['loss']
# Local RMSE score: 71.28947482982856
# ['loss']
# Local RMSE score: 30.803596601388847
# ['loss']
# Local RMSE score: 25.786804567541672
# ['loss']
# Local RMSE score: 40.245058197578736
# ['loss']
# Local RMSE score: 125.62470384443316
# ['loss']
# Local RMSE score: 13.912915238676675
# ['loss']
# Local RMSE score: 21.636334698265117
# ['loss']
# Local RMSE score: 16.90249697850879
# ['loss']
# Local RMSE score: 27.85392817467285
# ['loss']
# Local RMSE score: 15.273816877545489
# ['loss']
# Local RMSE score: 16.059669309511957
# ['loss']
# Local RMSE score: 32.75143670051426
# ['loss']
# Local RMSE score: 23.047674760535934
# ['loss']
# Local RMSE score: 44.53612547847536
# ['loss']
# Local RMSE score: 14.387224442792501
# ['loss']
# Local RMSE score: 15.301611696402462
# ['loss']
# Local RMSE score: 19.206473387866836
# ['loss']
# Local RMSE score: 21.00319672802864
# ['loss']
# Local RMSE score: 16.329311784356992
# ['loss']
# Local RMSE score: 65.71410814233819
# ['loss']
# Local RMSE score: 13.873330180052022
# ['loss']
# Local RMSE score: 135.2058839450532
# ['loss']
# Local RMSE score: 20.96885842902772
# ['loss']
# Local RMSE score: 14.23394664981639
# ['loss']
# Local RMSE score: 126.52963062881662
# ['loss']
# Local RMSE score: 16.36444889734899
# ['loss']
# Local RMSE score: 14.439172943473135
# ['loss']
# Local RMSE score: 32.9622981058697
# ['loss']
# Local RMSE score: 54.104326085809916
# ['loss']
# Local RMSE score: 38.913686807761806
# ['loss']
# Local RMSE score: 41.76185178300228
# ['loss']
# Local RMSE score: 29.54412711674713
# ['loss']
# Local RMSE score: 65.43309488985645
# ['loss']
# Local RMSE score: 22.1166217732868
# ['loss']
# Local RMSE score: 66.15522116684981
# ['loss']
# Local RMSE score: 22.7698163616603
# ['loss']
# Local RMSE score: 34.55493190675112
# ['loss']
# Local RMSE score: 42.08444653893078
# ['loss']
# Local RMSE score: 21.85629694651738
# ['loss']
# Local RMSE score: 24.857340774549183
# ['loss']
# Local RMSE score: 23.546819168075857
# ['loss']
# Local RMSE score: 27.06820656194754
# ['loss']
# Local RMSE score: 29.872160930326157
# ['loss']
# Local RMSE score: 84.24924193036408
# ['loss']
# Local RMSE score: 22.00172502603904
# ['loss']
# Local RMSE score: 44.06103660490292
# ['loss']
# Local RMSE score: 20.803928388387966
# ['loss']
# Local RMSE score: 33.326737512357546
# ['loss']
# Local RMSE score: 32.80622786554993
# ['loss']
# Local RMSE score: 97.19063475953509
# ['loss']
# Local RMSE score: 20.13792188071533
# ['loss']
# Local RMSE score: 155.22761247776236
# ['loss']
# Local RMSE score: 23.181709757782357
# ['loss']
# Local RMSE score: 23.143950260164615
# ['loss']
# Local RMSE score: 104.00666409629036
# ['loss']
# Local RMSE score: 27.858337368795237
# ['loss']
# Local RMSE score: 39.31988077103514
# ['loss']
# Local RMSE score: 60.217416470881396
# ['loss']
# Local RMSE score: 47.58077352865334
# ['loss']
# Local RMSE score: 27.281203049682603
# ['loss']
# Local RMSE score: 14.86543899806254
# ['loss']
# Local RMSE score: 15.170073691069659
# ['loss']
# Local RMSE score: 29.040391343204448
# ['loss']
# Local RMSE score: 39.076656106958744
# ['loss']
# Local RMSE score: 68.63156550939408
# ['loss']
# Local RMSE score: 20.807902425968358
# ['loss']
# Local RMSE score: 38.307399366974806
# ['loss']
# Local RMSE score: 17.56666502695097
# ['loss']
# Local RMSE score: 33.92436819970252
# ['loss']
# Local RMSE score: 23.176593424071836
# ['loss']
# Local RMSE score: 13.77466731942973
# ['loss']
# Local RMSE score: 60.15745496574867
# ['loss']
# Local RMSE score: 14.117277203977416
# ['loss']
# Local RMSE score: 27.133825049084503
# ['loss']
# Local RMSE score: 17.692870709485522
# ['loss']
# Local RMSE score: 33.732761304597524
# ['loss']
# Local RMSE score: 35.08642416952157
# ['loss']
# Local RMSE score: 14.178069620073781
# ['loss']
# Local RMSE score: 20.512683833463132
# ['loss']
# Local RMSE score: 18.21773641605832
# ['loss']
# Local RMSE score: 21.72834992616149
# ['loss']
# Local RMSE score: 133.84006087112414
# ['loss']
# Local RMSE score: 27.829336338651885
# ['loss']
# Local RMSE score: 13.877855173143237
# ['loss']
# Local RMSE score: 71.80583713819466
# ['loss']
# Local RMSE score: 14.350592840091682
# ['loss']
# Local RMSE score: 26.74988817269732
# ['loss']
# Local RMSE score: 28.52812419012383
# ['loss']
# Local RMSE score: 25.97834049270068
# ['loss']
# Local RMSE score: 19.735073126105302
# ['loss']
# Local RMSE score: 64.86539131034354
# ['loss']
# Local RMSE score: 20.183478361592748
# ['loss']
# Local RMSE score: 21.186077820455196
# ['loss']
# Local RMSE score: 80.07568013169364
# ['loss']
# Local RMSE score: 92.77978559440241
# ['loss']
# Local RMSE score: 22.854260442597642
# ['loss']
# Local RMSE score: 23.169735580530666
# ['loss']
# Local RMSE score: 33.71434157065358
# ['loss']
# Local RMSE score: 47.691860662132456
# ['loss']
# Local RMSE score: 27.207435292655667
# ['loss']
# Local RMSE score: 21.537850572449923
# ['loss']
# Local RMSE score: 25.955993450286634
# ['loss']
# Local RMSE score: 23.25206813447647
# ['loss']
# Local RMSE score: 29.501513219235402
# ['loss']
# Local RMSE score: 22.06593361700223
# ['loss']
# Local RMSE score: 39.65936867540112
# ['loss']
# Local RMSE score: 24.90611526876116
# ['loss']
# Local RMSE score: 48.20766358226554
# ['loss']
# Local RMSE score: 23.650338349424388
# ['loss']
# Local RMSE score: 24.700461319052934
# ['loss']
# Local RMSE score: 20.40723446115426
# ['loss']
# Local RMSE score: 32.89635913393403
# ['loss']
# Local RMSE score: 26.667813318922196
# ['loss']
# Local RMSE score: 22.898248130471707
# ['loss']
# Local RMSE score: 59.31443744753712
# ['loss']
# Local RMSE score: 30.795112714816124
# ['loss']
# Local RMSE score: 24.75020371994424
# ['loss']
# Local RMSE score: 20.130070101144106
# ['loss']
# Local RMSE score: 78.41673968256235
# ['loss']
# Local RMSE score: 25.309845821210367
# ['loss']
# Local RMSE score: 91.49690422767709
# ['loss']
# Local RMSE score: 19.91477357318041
# ['loss']
# Local RMSE score: 25.447907270795916
# ['loss']
# Local RMSE score: 33.43667580245595
# ['loss']
# Local RMSE score: 130.3828739466409
# ['loss']
# Local RMSE score: 13.764050583440216
# ['loss']
# Local RMSE score: 24.231305324610695
# ['loss']
# Local RMSE score: 14.110254448262285
# ['loss']
# Local RMSE score: 41.70016594265179
# ['loss']
# Local RMSE score: 17.568222798128364
# ['loss']
# Local RMSE score: 15.918051239846681
# ['loss']
# Local RMSE score: 34.559006519280366
# ['loss']
# Local RMSE score: 23.83604293306979
# ['loss']
# Local RMSE score: 62.7254738103993
# ['loss']
# Local RMSE score: 13.801862240492957
# ['loss']
# Local RMSE score: 15.908628618956724
# ['loss']
# Local RMSE score: 28.230701009873595
# ['loss']
# Local RMSE score: 45.51541523773858
# ['loss']
# Local RMSE score: 13.847957584108093
# ['loss']
# Local RMSE score: 47.78922258104234
# ['loss']
# Local RMSE score: 14.408798214630586
# ['loss']
# Local RMSE score: 64.62226267062135
# ['loss']
# Local RMSE score: 19.948074781664257
# ['loss']
# Local RMSE score: 14.082566807825446
# ['loss']
# Local RMSE score: 141.976937323789
# ['loss']
# Local RMSE score: 40.00080876679055
# ['loss']
# Local RMSE score: 14.487248547892987
# ['loss']
# Local RMSE score: 31.10230955452732
# ['loss']
# Local RMSE score: 97.36496019468714
# ['loss']
# Local RMSE score: 20.442431776233057
# ['loss']
# Local RMSE score: 120.14340949086825
# ['loss']
# Local RMSE score: 19.452092063535485
# ['loss']
# Local RMSE score: 57.33462418237492
# ['loss']
# Local RMSE score: 23.48106260087839
# ['loss']
# Local RMSE score: 281.9841610567435
# ['loss']
# Local RMSE score: 22.27358224570468
# ['loss']
# Local RMSE score: 27.224530015360244
# ['loss']
# Local RMSE score: 19.68568570608885
# ['loss']
# Local RMSE score: 24.761649111830057
# ['loss']
# Local RMSE score: 26.653389893589026
# ['loss']
# Local RMSE score: 21.786413311481184
# ['loss']
# Local RMSE score: 65.37228979658245
# ['loss']
# Local RMSE score: 21.259489558443278
# ['loss']
# Local RMSE score: 78.71189633836168
# ['loss']
# Local RMSE score: 19.748322735752293
# ['loss']
# Local RMSE score: 19.56940193841801
# ['loss']
# Local RMSE score: 21.89646755086248
# ['loss']
# Local RMSE score: 85.87053532989454
# ['loss']
# Local RMSE score: 23.795885426333758
# ['loss']
# Local RMSE score: 57.554553559883935
# ['loss']
# Local RMSE score: 22.383176544337612
# ['loss']
# Local RMSE score: 145.07992188462856
# ['loss']
# Local RMSE score: 21.731324161598458
# ['loss']
# Local RMSE score: 22.305112546954213
# ['loss']
# Local RMSE score: 218.1609174279209
# ['loss']
# Local RMSE score: 31.180050457622258
# ['loss']
# Local RMSE score: 52.46421461168088
# ['loss']
# Local RMSE score: 46.50575038459269
# ['loss']
# Local RMSE score: 71.37740410642854
# ['loss']
# Local RMSE score: 20.272218947298402
# ['loss']
# Local RMSE score: 104.96077003629593
# ['loss']
# Local RMSE score: 15.961254841197206
# ['loss']
# Local RMSE score: 46.798594112156024
# ['loss']
# Local RMSE score: 53.65321300597492
# ['loss']
# Local RMSE score: 145.56641685255602
# ['loss']
# Local RMSE score: 19.11718142744232
# ['loss']
# Local RMSE score: 30.230561499376197
# ['loss']
# Local RMSE score: 25.34736835398747
# ['loss']
# Local RMSE score: 24.6099986134159
# ['loss']
# Local RMSE score: 18.1632064367252
# ['loss']
# Local RMSE score: 14.299468851681029
# ['loss']
# Local RMSE score: 32.24468480041258
# ['loss']
# Local RMSE score: 14.856547005854669
# ['loss']
# Local RMSE score: 32.433444692429916
# ['loss']
# Local RMSE score: 15.811843942700296
# ['loss']
# Local RMSE score: 27.338035185593483
# ['loss']
# Local RMSE score: 30.483355242137588
# ['loss']
# Local RMSE score: 40.65597333281296
# ['loss']
# Local RMSE score: 31.275195676453244
# ['loss']
# Local RMSE score: 26.849173832162595
# ['loss']
# Local RMSE score: 15.147622130990467
# ['loss']
# Local RMSE score: 113.91030039409567
# ['loss']
# Local RMSE score: 14.935041354463491
# ['loss']
# Local RMSE score: 13.803233672780467
# ['loss']
# Local RMSE score: 195.1783117343478
# ['loss']
# Local RMSE score: 15.84080013817625
# ['loss']
# Local RMSE score: 23.681109258688622
# ['loss']
# Local RMSE score: 29.634544658996436
# ['loss']
# Local RMSE score: 26.034744288307884
# ['loss']
# Local RMSE score: 24.522420134559752
# ['loss']
# Local RMSE score: 74.52894965403196
# ['loss']
# Local RMSE score: 24.772675413018227
# ['loss']
# Local RMSE score: 51.15047338784399
# ['loss']
# Local RMSE score: 118.42408354460899
# ['loss']
# Local RMSE score: 26.555710443921345
# ['loss']
# Local RMSE score: 21.93813394244289
# ['loss']
# Local RMSE score: 31.125020183956078
# ['loss']
# Local RMSE score: 20.736693974126176
# ['loss']
# Local RMSE score: 35.43538156580817
# ['loss']
# Local RMSE score: 51.85557022116158
# ['loss']
# Local RMSE score: 23.177025521084783
# ['loss']
# Local RMSE score: 67.58937058031468
# ['loss']
# Local RMSE score: 25.21218528243691
# ['loss']
# Local RMSE score: 41.77422557743012
# ['loss']
# Local RMSE score: 21.570047615970967
# ['loss']
# Local RMSE score: 23.12669569158968
# ['loss']
# Local RMSE score: 51.98399388689428
# ['loss']
# Local RMSE score: 29.02485167238896
# ['loss']
# Local RMSE score: 25.835739724272262
# ['loss']
# Local RMSE score: 43.1184534358655
# ['loss']
# Local RMSE score: 23.141168492493453
# ['loss']
# Local RMSE score: 43.289182741143875
# ['loss']
# Local RMSE score: 22.661701942943758
# ['loss']
# Local RMSE score: 22.54044355266794
# ['loss']
# Local RMSE score: 36.720596277362276
# ['loss']
# Local RMSE score: 22.299448475887225
# ['loss']
# Local RMSE score: 45.53280566210837
# ['loss']
# Local RMSE score: 44.814540213223964
# ['loss']
# Local RMSE score: 129.75754236822695
# ['loss']
# Local RMSE score: 33.971440684681994
# ['loss']
# Local RMSE score: 22.967184585915547
# ['loss']
# Local RMSE score: 26.521228056199607
# ['loss']
# Local RMSE score: 15.963647300031864
# ['loss']
# Local RMSE score: 73.75347301224315
# ['loss']
# Local RMSE score: 107.94975487819616
# ['loss']
# Local RMSE score: 14.660693059031047
# ['loss']
# Local RMSE score: 28.830484713423168
# ['loss']
# Local RMSE score: 14.189077190187382
# ['loss']
# Local RMSE score: 30.31263939236652
# ['loss']
# Local RMSE score: 16.16551765238957
# ['loss']
# Local RMSE score: 21.36536631254186
# ['loss']
# Local RMSE score: 28.14658769299733
# ['loss']
# Local RMSE score: 18.189647404965807
# ['loss']
# Local RMSE score: 44.26819405135077
# ['loss']
# Local RMSE score: 13.803965139325385
# ['loss']
# Local RMSE score: 25.25364799227501
# ['loss']
# Local RMSE score: 49.57706781226531
# ['loss']
# Local RMSE score: 14.610617233619053
# ['loss']
# Local RMSE score: 13.743475669769971
# ['loss']
# Local RMSE score: 48.405929419199396
# ['loss']
# Local RMSE score: 13.963232502343459
# ['loss']
# Local RMSE score: 76.07447966427675
# ['loss']
# Local RMSE score: 18.630089508789574
# ['loss']
# Local RMSE score: 14.186554800541401
# ['loss']
# Local RMSE score: 113.24697797040882
# ['loss']
# Local RMSE score: 15.942717148340687
# ['loss']
# Local RMSE score: 15.67587647847122
# ['loss']
# Local RMSE score: 15.485100767129154
# ['loss']
# Local RMSE score: 102.64369206662256
# ['loss']
# Local RMSE score: 32.77499485243895
# ['loss']
# Local RMSE score: 75.87640700899942
# ['loss']
# Local RMSE score: 30.449825182486542
# ['loss']
# Local RMSE score: 101.60300206923263
# ['loss']
# Local RMSE score: 51.52323393170817
# ['loss']
# Local RMSE score: 79.61678326530213
# ['loss']
# Local RMSE score: 23.501247232263992
# ['loss']
# Local RMSE score: 20.11811621991107
# ['loss']
# Local RMSE score: 27.852572674726794
# ['loss']
# Local RMSE score: 21.65524053154469
# ['loss']
# Local RMSE score: 24.82317376198588
# ['loss']
# Local RMSE score: 29.5957552624679
# ['loss']
# Local RMSE score: 24.44858639815137
# ['loss']
# Local RMSE score: 28.547070782825752
# ['loss']
# Local RMSE score: 97.0301845980694
# ['loss']
# Local RMSE score: 21.86682863049292
# ['loss']
# Local RMSE score: 21.6368589110239
# ['loss']
# Local RMSE score: 26.721577785992892
# ['loss']
# Local RMSE score: 31.39129418518077
# ['loss']
# Local RMSE score: 25.552361506993993
# ['loss']
# Local RMSE score: 136.09773301929175
# ['loss']
# Local RMSE score: 21.38254285169167
# ['loss']
# Local RMSE score: 107.34950511963916
# ['loss']
# Local RMSE score: 21.628470600037403
# ['loss']
# Local RMSE score: 22.110250189815815
# ['loss']
# Local RMSE score: 100.71382216936784
# ['loss']
# Local RMSE score: 30.082863583733413
# ['loss']
# Local RMSE score: 20.526044278439617
# ['loss']
# Local RMSE score: 50.68662884335176
# ['loss']
# Local RMSE score: 75.31733952357993
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ]
#  ]
# RMSE Score with pyswarm Optimization is : 22.17015593581483
